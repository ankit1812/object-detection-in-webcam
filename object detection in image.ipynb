# %%
from darkflow.net.build import TFNet

# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='svg'

# %%
options={
    'model':'cfg/yolo.cfg',
    'load':'bin/yolo.weights',
    'threshold':0.3
    
    
}

# %%
tfnet=TFNet(options)
# Out:
# Parsing ./cfg/yolo.cfg
# Parsing cfg/yolo.cfg
# Loading bin/yolo.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.9019973278045654s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From C:\Users\craterzone\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#        |        | input                            | (?, 608, 608, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
# ...

# %%
img=cv2.imread('C:\\Users\\craterzone\\Desktop\\YOLO\\darkflow-master\\sample_img\\sample_giraffe.jpg')

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
result=tfnet.return_predict(img)

# %%
result[0]['label']
# Out:
# 'zebra'

# %%
result
# Out:
# [{'label': 'zebra',
#   'confidence': 0.80854577,
#   'topleft': {'x': 310, 'y': 213},
#   'bottomright': {'x': 417, 'y': 442}},
#  {'label': 'giraffe',
#   'confidence': 0.8888611,
#   'topleft': {'x': 162, 'y': 0},
#   'bottomright': {'x': 441, 'y': 440}}]

# %%
t2=(result[0]['bottomright']['x'],result[0]['bottomright']['y'])
t1=(result[0]['topleft']['x'],result[0]['topleft']['y'])
label1=(result[0]['label'])
label2=(result[1]['label'])
x2=(result[1]['bottomright']['x'],result[0]['bottomright']['y'])
x1=(result[1]['topleft']['x'],result[0]['topleft']['y'])

# %%
label1
# Out:
# 'zebra'

# %%
img=cv2.rectangle(img,t1,t2,(255,0,0),4)
img=cv2.rectangle(img,x1,x2,(255,255,0),4)

# %%
plt.imshow(img)

# %%
pwd
# Out:
# 'C:\\Users\\craterzone\\Desktop\\YOLO\\darkflow-master'
